# %%
#needed dependencies for io in Drive
# !pip install -U -q PyDrive
# !pip install h5py
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
from google.colab import drive
drive.mount('/content/drive')
# !ls "/content/drive/MyDrive/CST/L98/"
# Out:
# ...
# WARNING:root:pydrive is deprecated and no longer maintained. We recommend that you migrate your projects to pydrive2, the maintained fork of pydrive
# Mounted at /content/drive
# '5K Baseline.ipynb'		   l2-rerank.sdp
#  aug				   L98_2.sdp
#  Augmented_2.ipynb		   large.sdp
#  Augmented.ipynb		   Mixed.ipynb
#  biaffine_parser.py		   mixed.sdp
# 'Biaffine Sentence_Length.ipynb'   model
#  convert.py			  'Model Outputs'
#  data.py			   modules.py
#  dm_5000.sdp			   multilingual_MBERT.ipynb
#  DM_500.ipynb			   multilingual_Parser.ipynb
#  dm_500.sdp			   multilingual_XLM.ipynb
#  dm.sdp				   __pycache__
#  eval_dep.py			   readme
# 'Evaluation Code.gdoc'		   sdp_graph.py
#  extrinsic			   significance
#  Extrinsic.ipynb		   small.sdp
# 'FINAL_Biaffine Parser.ipynb'	  'Training Biaffine Semantic Dependency Parser.ipynb'
#  indexed_data.py		   train_or_use_parser.py
#  indexing.py			   Untitled
#  l1-rerank.sdp

# %%
f = open("/content/drive/MyDrive/CST/L98/dm.sdp")
sentences = {}
current = ["", ""]
col_names = [["sentid"], ["form"], ["lemma"]]
index = []
for line in f.readlines():
  if len(line) > 0:
      if line[0] == "#":
          if current[0] != "#":
              sentences[current[0]] = current[1]
              index.append(current[0])
          current[0] = int(line[1:])
          current[1] = ""
      else:
          current[1] += line
index.pop()
# Out:
# 22098002

# %%
import random
n = 5000
sent_id = random.sample(index, n)

# %%
with open('/content/drive/MyDrive/CST/L98/dm_5000.sdp', 'w') as f:
  f.write("\n\n")
  for indices in sent_id:
    f.write("#" + str(indices) + "\n")
    f.write(sentences[indices])

# %% [markdown]
# Training the model

# %%
# !pip install sacremoses
# !python3 "/content/drive/MyDrive/CST/L98/train_or_use_parser.py" train "/content/drive/MyDrive/CST/L98/dm_5000.sdp" "/content/drive/MyDrive/CST/L98/model/5000/" -g sdp -v "/content/drive/MyDrive/CST/L98/dm_5000.sdp" -e loss
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 8.2 MB/s eta 0:00:00
# ...
# 2023-12-14 20:28:05.962272: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-14 20:28:05.962321: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-14 20:28:05.963633: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-14 20:28:07.161162: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# tokenizer_config.json: 100% 29.0/29.0 [00:00<00:00, 172kB/s]
# config.json: 100% 570/570 [00:00<00:00, 3.03MB/s]
# ...

# %%
# !python3 "/content/drive/MyDrive/CST/L98/train_or_use_parser.py" test "/content/drive/MyDrive/CST/L98/l1-rerank.sdp" "/content/drive/MyDrive/CST/L98/model/5000" -g sdp --out_parsed_file training.txt
# Out:
# 2023-12-14 20:46:01.519436: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-14 20:46:01.519495: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-14 20:46:01.521744: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-14 20:46:03.308630: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Parsing /content/drive/MyDrive/CST/L98/l1-rerank.sdp with /content/drive/MyDrive/CST/L98/model/5000/model ...
# loaded model /content/drive/MyDrive/CST/L98/model/5000/model
# Max sentence length: {'toparse': 63}
# ...

# %%
# !python3 "/content/drive/MyDrive/CST/L98/train_or_use_parser.py" test "/content/drive/MyDrive/CST/L98/l2-rerank.sdp" "/content/drive/MyDrive/CST/L98/model/5000" -g sdp --out_parsed_file l2.txt
# Out:
# 2023-12-14 20:48:40.713430: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-14 20:48:40.713490: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-14 20:48:40.714800: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-14 20:48:42.167217: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Parsing /content/drive/MyDrive/CST/L98/l2-rerank.sdp with /content/drive/MyDrive/CST/L98/model/5000/model ...
# loaded model /content/drive/MyDrive/CST/L98/model/5000/model
# Max sentence length: {'toparse': 59}
# ...

# %%
# !python3 "/content/drive/MyDrive/CST/L98/eval_dep.py" training.txt.l
# Out:
# ALL UR 37.36 UP 72.57 UF 49.33
# ALL LR 35.16 LP 68.30 LF 46.42
# >40 UR 17.00 UP 68.21 UF 27.22
# >40 LR 15.58 LP 62.50 LF 24.94
# LABEL          ARG1 GOLD DIST:  0.78 (MAD  2.47) PRED DIST:  0.52 (MAD  1.53)
# LABEL          ARG1 GOLD DIR :  0.24 (MAD  0.94) PRED DIR :  0.27 (MAD  0.91)
# LABEL          ARG2 GOLD DIST: -1.79 (MAD  1.25) PRED DIST: -1.35 (MAD  1.46)
# LABEL          ARG2 GOLD DIR : -0.85 (MAD  0.27) PRED DIR : -0.63 (MAD  0.61)
# LABEL          ARG3 GOLD DIST: -2.75 (MAD  1.77) PRED DIST:  0.00 (MAD  0.00)
# LABEL          ARG3 GOLD DIR : -0.90 (MAD  0.19) PRED DIR :  0.00 (MAD  0.00)
# LABEL          ARG4 GOLD DIST: -1.50 (MAD  3.50) PRED DIST:  0.00 (MAD  0.00)
# LABEL          ARG4 GOLD DIR : -0.73 (MAD  0.47) PRED DIR :  0.00 (MAD  0.00)
# LABEL            BV GOLD DIST: -1.39 (MAD  0.53) PRED DIST: -1.50 (MAD  0.81)
# LABEL            BV GOLD DIR : -1.00 (MAD  0.00) PRED DIR : -0.93 (MAD  0.13)
# ...

# %%
# !python3 "/content/drive/MyDrive/CST/L98/eval_dep.py" l2.txt.l
# Out:
# ALL UR 36.57 UP 70.80 UF 48.23
# ALL LR 34.22 LP 66.25 LF 45.13
# >40 UR 14.25 UP 69.16 UF 23.63
# >40 LR 13.04 LP 63.31 LF 21.63
# LABEL          ARG1 GOLD DIST:  0.85 (MAD  2.41) PRED DIST:  0.53 (MAD  1.47)
# LABEL          ARG1 GOLD DIR :  0.26 (MAD  0.93) PRED DIR :  0.29 (MAD  0.90)
# LABEL          ARG2 GOLD DIST: -1.68 (MAD  1.44) PRED DIST: -1.36 (MAD  1.40)
# LABEL          ARG2 GOLD DIR : -0.83 (MAD  0.32) PRED DIR : -0.65 (MAD  0.58)
# LABEL          ARG3 GOLD DIST: -2.44 (MAD  2.29) PRED DIST:  0.00 (MAD  0.00)
# LABEL          ARG3 GOLD DIR : -0.80 (MAD  0.37) PRED DIR :  0.00 (MAD  0.00)
# LABEL          ARG4 GOLD DIST: -2.38 (MAD  2.79) PRED DIST:  0.00 (MAD  0.00)
# LABEL          ARG4 GOLD DIR : -0.69 (MAD  0.52) PRED DIR :  0.00 (MAD  0.00)
# LABEL            BV GOLD DIST: -1.39 (MAD  0.53) PRED DIST: -1.48 (MAD  0.80)
# LABEL            BV GOLD DIR : -1.00 (MAD  0.00) PRED DIR : -0.93 (MAD  0.13)
# ...

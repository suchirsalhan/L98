# %%
#needed dependencies for io in Drive
# !pip install -U -q PyDrive
# !pip install h5py
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
from google.colab import drive
drive.mount('/content/drive')
# !ls "/content/drive/MyDrive/CST/L98/"
# Out:
# ...
# WARNING:root:pydrive is deprecated and no longer maintained. We recommend that you migrate your projects to pydrive2, the maintained fork of pydrive
# Mounted at /content/drive
#  aug				   l1-rerank.sdp
#  Augmented_2.ipynb		   l2-rerank.sdp
#  Augmented.ipynb		   L98_2.sdp
#  biaffine_parser.py		   large.sdp
# 'Biaffine Sentence_Length.ipynb'   Mixed.ipynb
#  conll09_ENG_test.conllu	   model
#  conll09_ENG_test.sdp		  'Model Outputs'
#  convert.py			   modules.py
#  data.py			   multilingual_MBERT.ipynb
#  DM_500.ipynb			   multilingual_Parser.ipynb
#  dm_500.sdp			   multilingual_XLM.ipynb
#  dm.sdp				   __pycache__
#  eval_dep.py			   readme
# 'Evaluation Code.gdoc'		   sdp_graph.py
#  extrinsic			   significance
#  Extrinsic.ipynb		   small.sdp
# 'FINAL_Biaffine Parser.ipynb'	  'Training Biaffine Semantic Dependency Parser.ipynb'
#  indexed_data.py		   train_or_use_parser.py
#  indexing.py			   Untitled0.ipynb

# %%
# !pip install sacremoses
# !python3 "/content/drive/MyDrive/CST/L98/train_or_use_parser.py" train "/content/drive/MyDrive/CST/L98/dm_500.sdp" "/content/drive/MyDrive/CST/L98/model/500" -g sdp -v "/content/drive/MyDrive/CST/L98/dm_500.sdp" -e loss
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 11.9 MB/s eta 0:00:00
# ...
# 2023-12-14 15:02:49.351216: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-14 15:02:49.351296: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-14 15:02:49.351359: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-14 15:02:50.810677: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# tokenizer_config.json: 100% 29.0/29.0 [00:00<00:00, 109kB/s]
# config.json: 100% 570/570 [00:00<00:00, 2.44MB/s]
# ...

# %%
# !python3 "/content/drive/MyDrive/CST/L98/train_or_use_parser.py" test "/content/drive/MyDrive/CST/L98/l1-rerank.sdp" "/content/drive/MyDrive/CST/L98/model/500" -g sdp --out_parsed_file training.txt
# Out:
# 2023-12-14 16:12:46.266889: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-14 16:12:46.266993: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-14 16:12:46.267035: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-14 16:12:47.831971: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Parsing /content/drive/MyDrive/CST/L98/l1-rerank.sdp with /content/drive/MyDrive/CST/L98/model/500/model ...
# loaded model /content/drive/MyDrive/CST/L98/model/500/model
# Max sentence length: {'toparse': 63}
# ...

# %%
# !python3 "/content/drive/MyDrive/CST/L98/eval_dep.py" training.txt.l
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/CST/L98/eval_dep.py", line 234, in <module>
#     UP = 100 * nb_correct_u / nb_pred
# ZeroDivisionError: division by zero

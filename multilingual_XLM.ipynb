# %%
#needed dependencies for io in Drive
# !pip install -U -q PyDrive
# !pip install h5py
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
from google.colab import drive
drive.mount('/content/drive')
# !ls "/content/drive/MyDrive/CST/L98/"
# Out:
# ...
# WARNING:root:pydrive is deprecated and no longer maintained. We recommend that you migrate your projects to pydrive2, the maintained fork of pydrive
# Mounted at /content/drive
#  biaffine_parser.py		   model
# 'Biaffine Sentence_Length.ipynb'  'Model Outputs'
#  DA_2.ipynb			   modules.py
#  data.py			   multilingual_MBART.ipynb
#  dm_500.sdp			   multilingual_MBERT.ipynb
#  dm.sdp				   multilingual_Parser.ipynb
#  eval_dep.py			   multilingual_XLM.ipynb
# 'Evaluation Code.gdoc'		   __pycache__
# 'FINAL_Biaffine Parser.ipynb'	   readme
#  indexed_data.py		   small_aug.txt
#  indexing.py			   small.sdp
#  l1-rerank.sdp			  'Training Biaffine Semantic Dependency Parser.ipynb'
#  l2-rerank.sdp			   train_or_use_parser.py
#  L98_2.sdp			   Untitled0.ipynb
#  large_aug.txt			   Untitled1.ipynb
#  large.sdp

# %%
f = open("/content/drive/MyDrive/CST/L98/dm.sdp")
sentences = {}
current = ["", ""]
col_names = [["sentid"], ["form"], ["lemma"]]
index = []
for line in f.readlines():
  if len(line) > 0:
      if line[0] == "#":
          if current[0] != "#":
              sentences[current[0]] = current[1]
              index.append(current[0])
          current[0] = int(line[1:])
          current[1] = ""
      else:
          current[1] += line

# %%
# !pip install sacremoses
# !python3 "/content/drive/MyDrive/CST/L98/train_or_use_parser.py" train "/content/drive/MyDrive/CST/L98/dm.sdp" "/content/drive/MyDrive/CST/L98/model/multilingual/XLM" -g sdp -v "/content/drive/MyDrive/CST/L98/dm.sdp" -e loss --bert_name "xlm-mlm-tlm-xnli15-1024"
# Out:
# ...
# 2023-12-11 20:35:32.455199: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-11 20:35:32.455258: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-11 20:35:32.455292: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-11 20:35:33.631110: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# tokenizer_config.json: 100% 401/401 [00:00<00:00, 2.40MB/s]
# config.json: 100% 1.40k/1.40k [00:00<00:00, 8.09MB/s]
# vocab.json: 100% 2.95M/2.95M [00:01<00:00, 2.57MB/s]
# merges.txt: 100% 1.43M/1.43M [00:00<00:00, 44.4MB/s]
# ...

# %% [markdown]
# l1-rerank

# %%
# !python3 "/content/drive/MyDrive/CST/L98/train_or_use_parser.py" test "/content/drive/MyDrive/CST/L98/l1-rerank.sdp" "/content/drive/MyDrive/CST/L98/model/multilingual/XLM" -g sdp --out_parsed_file training.txt
# Out:
# 2023-12-11 23:14:36.157340: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-11 23:14:36.157389: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-11 23:14:36.157426: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-11 23:14:37.329669: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# tokenizer_config.json: 100% 29.0/29.0 [00:00<00:00, 142kB/s]
# config.json: 100% 570/570 [00:00<00:00, 3.43MB/s]
# vocab.txt: 100% 213k/213k [00:00<00:00, 19.7MB/s]
# tokenizer.json: 100% 436k/436k [00:00<00:00, 29.0MB/s]
# ...

# %%
# !python3 "/content/drive/MyDrive/CST/L98/eval_dep.py" training.txt.l
# Out:
# ALL UR 87.80 UP 81.43 UF 84.50
# ALL LR 80.56 LP 74.72 LF 77.53
# >40 UR 81.46 UP 78.30 UF 79.85
# >40 LR 75.58 LP 72.64 LF 74.08
# LABEL          ARG1 GOLD DIST:  0.78 (MAD  2.47) PRED DIST:  0.58 (MAD  2.59)
# LABEL          ARG1 GOLD DIR :  0.24 (MAD  0.94) PRED DIR :  0.19 (MAD  0.96)
# LABEL          ARG2 GOLD DIST: -1.79 (MAD  1.25) PRED DIST: -1.92 (MAD  1.28)
# LABEL          ARG2 GOLD DIR : -0.85 (MAD  0.27) PRED DIR : -0.85 (MAD  0.27)
# LABEL          ARG3 GOLD DIST: -2.75 (MAD  1.77) PRED DIST: -2.81 (MAD  1.61)
# LABEL          ARG3 GOLD DIR : -0.90 (MAD  0.19) PRED DIR : -0.95 (MAD  0.10)
# LABEL          ARG4 GOLD DIST: -1.50 (MAD  3.50) PRED DIST:  0.00 (MAD  0.00)
# LABEL          ARG4 GOLD DIR : -0.73 (MAD  0.47) PRED DIR :  0.00 (MAD  0.00)
# LABEL            BV GOLD DIST: -1.39 (MAD  0.53) PRED DIST: -1.39 (MAD  0.54)
# LABEL            BV GOLD DIR : -1.00 (MAD  0.00) PRED DIR : -1.00 (MAD  0.00)
# ...

# %% [markdown]
# l2-rerank

# %%
# !python3 "/content/drive/MyDrive/CST/L98/train_or_use_parser.py" test "/content/drive/MyDrive/CST/L98/l2-rerank.sdp" "/content/drive/MyDrive/CST/L98/model/multilingual/XLM" -g sdp --out_parsed_file l2.txt
# Out:
# 2023-12-11 23:18:13.656181: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-11 23:18:13.656232: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-11 23:18:13.656274: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-11 23:18:14.889743: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Parsing /content/drive/MyDrive/CST/L98/l2-rerank.sdp with /content/drive/MyDrive/CST/L98/model/multilingual/XLM/model ...
# loaded model /content/drive/MyDrive/CST/L98/model/multilingual/XLM/model
# ...

# %%
# !python3 "/content/drive/MyDrive/CST/L98/eval_dep.py" l2.txt.l
# Out:
# ALL UR 82.92 UP 77.24 UF 79.98
# ALL LR 75.98 LP 70.77 LF 73.28
# >40 UR 75.12 UP 73.88 UF 74.49
# >40 LR 69.50 LP 68.36 LF 68.92
# LABEL          ARG1 GOLD DIST:  0.85 (MAD  2.41) PRED DIST:  0.66 (MAD  2.49)
# LABEL          ARG1 GOLD DIR :  0.26 (MAD  0.93) PRED DIR :  0.21 (MAD  0.95)
# LABEL          ARG2 GOLD DIST: -1.68 (MAD  1.44) PRED DIST: -1.87 (MAD  1.27)
# LABEL          ARG2 GOLD DIR : -0.83 (MAD  0.32) PRED DIR : -0.85 (MAD  0.28)
# LABEL          ARG3 GOLD DIST: -2.44 (MAD  2.29) PRED DIST: -2.86 (MAD  1.62)
# LABEL          ARG3 GOLD DIR : -0.80 (MAD  0.37) PRED DIR : -0.96 (MAD  0.07)
# LABEL          ARG4 GOLD DIST: -2.38 (MAD  2.79) PRED DIST:  0.00 (MAD  0.00)
# LABEL          ARG4 GOLD DIR : -0.69 (MAD  0.52) PRED DIR :  0.00 (MAD  0.00)
# LABEL            BV GOLD DIST: -1.39 (MAD  0.53) PRED DIST: -1.38 (MAD  0.53)
# LABEL            BV GOLD DIR : -1.00 (MAD  0.00) PRED DIR : -1.00 (MAD  0.01)
# ...

# %% [markdown]
# # **SMALL**

# %% [markdown]
# # **LARGE**

# %% [markdown]
# # **XLM without Embeddings**

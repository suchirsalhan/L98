# %%
# !pip install sacremoses
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 5.3 MB/s eta 0:00:00
# ...

# %%
#!python3 train_or_use_parser.py train dm.sdp modeldir -g sdp -v dm.sdp -e loss

# %%
# !python3 train_or_use_parser.py train dm_500.sdp model_dir -g sdp -v dm_500.sdp -e loss
# Out:
# 2023-12-06 14:38:29.545432: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-06 14:38:29.545505: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-06 14:38:29.545558: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-06 14:38:30.797716: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# tokenizer_config.json: 100% 29.0/29.0 [00:00<00:00, 118kB/s]
# config.json: 100% 570/570 [00:00<00:00, 2.31MB/s]
# vocab.txt: 100% 213k/213k [00:00<00:00, 5.10MB/s]
# tokenizer.json: 100% 436k/436k [00:00<00:00, 26.4MB/s]
# ...

# %% [markdown]
# Test

# %%
# !python3 train_or_use_parser.py test dm_500.sdp model_dir -g sdp --out_parsed_file training.txt
# Out:
# 2023-12-06 14:41:43.320276: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-06 14:41:43.320346: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-06 14:41:43.320385: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-06 14:41:45.157182: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Parsing dm_500.sdp with model_dir/model ...
# loaded model model_dir/model
# Max sentence length: {'toparse': 56}
# parsing and evaluating conll file dm_500.sdp
# ...

# %%
# !python3 train_or_use_parser.py test l1-rerank.sdp model_dir -g sdp --out_parsed_file training.txt
# Out:
# 2023-12-06 14:58:47.243109: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-06 14:58:47.243173: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-06 14:58:47.243214: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-06 14:58:48.559676: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Parsing l1-rerank.sdp with model_dir/model ...
# loaded model model_dir/model
# Max sentence length: {'toparse': 63}
# parsing and evaluating conll file l1-rerank.sdp
# ...

# %%
# !python3 eval_dep.py training.txt.l
# Out:
# Traceback (most recent call last):
#   File "/content/eval_dep.py", line 234, in <module>
#     UP = 100 * nb_correct_u / nb_pred
# ZeroDivisionError: division by zero

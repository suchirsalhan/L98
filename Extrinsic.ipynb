# %%
#needed dependencies for io in Drive
# !pip install -U -q PyDrive
# !pip install h5py
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
from google.colab import drive
drive.mount('/content/drive')
# !ls "/content/drive/MyDrive/CST/L98/"
# Out:
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#  biaffine_parser.py		   large.sdp
# 'Biaffine Sentence_Length.ipynb'   Mixed.ipynb
#  conll09_ENG_test.conllu	   model
#  conll09_ENG_test.sdp		  'Model Outputs'
#  convert.py			   modules.py
#  DA_2.ipynb			   multilingual_MBERT.ipynb
#  data.py			   multilingual_Parser.ipynb
#  dm_500.sdp			   multilingual_XLM.ipynb
#  dm.sdp				   __pycache__
#  eval_dep.py			   readme
# 'Evaluation Code.gdoc'		   sdp_graph.py
#  Extrinsic.ipynb		   small_aug.txt
# 'FINAL_Biaffine Parser.ipynb'	   small.sdp
#  indexed_data.py		  'Training Biaffine Semantic Dependency Parser.ipynb'
#  indexing.py			   train_or_use_parser.py
#  l1-rerank.sdp			   Untitled0.ipynb
#  l2-rerank.sdp			   Untitled1.ipynb
#  L98_2.sdp			   Untitled2.ipynb
#  large_aug.txt

# %%
# !python3 "/content/drive/MyDrive/CST/L98/convert.py" read_file "/content/drive/MyDrive/CST/L98/conll09_ENG_test.conllu"

# %%
# !python3 "/content/drive/MyDrive/CST/L98/convert.py" convert_to_semeval15 "/content/drive/MyDrive/CST/L98/conll09_ENG_test.conllu"

# %%
f = to_dumb("/content/drive/MyDrive/CST/L98/conll09_ENG_test.conllu")

# %%
# !python3 "/content/drive/MyDrive/CST/L98/train_or_use_parser.py" test "/content/drive/MyDrive/CST/L98/conll09_ENG_test.sdp" "/content/drive/MyDrive/CST/L98/model/large" -g sdp --out_parsed_file training.txt
# Out:
# 2023-12-13 09:34:55.403156: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-13 09:34:55.403222: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-13 09:34:55.403259: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-13 09:34:56.707764: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Parsing /content/drive/MyDrive/CST/L98/conll09_ENG_test.sdp with /content/drive/MyDrive/CST/L98/model/large/model ...
# loaded model /content/drive/MyDrive/CST/L98/model/large/model
# Max sentence length: {'toparse': 0}
# ...

# %%
# !python3 "/content/drive/MyDrive/CST/L98/eval_dep.py" training.txt.l
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/CST/L98/eval_dep.py", line 233, in <module>
#     UR = 100 * nb_correct_u / nb_gold
# ZeroDivisionError: division by zero

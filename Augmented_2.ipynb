# %%
#needed dependencies for io in Drive
# !pip install -U -q PyDrive
# !pip install h5py
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
from google.colab import drive
drive.mount('/content/drive')
# !ls "/content/drive/MyDrive/CST/L98/"
# Out:
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#  aug				   l1-rerank.sdp
#  Augmented_2.ipynb		   l2-rerank.sdp
#  Augmented.ipynb		   L98_2.sdp
#  biaffine_parser.py		   large.sdp
# 'Biaffine Sentence_Length.ipynb'   Mixed.ipynb
#  conll09_ENG_test.conllu	   model
#  conll09_ENG_test.sdp		  'Model Outputs'
#  convert.py			   modules.py
#  data.py			   multilingual_MBERT.ipynb
#  dm_500.sdp			   multilingual_Parser.ipynb
#  dm.sdp				   multilingual_XLM.ipynb
#  eval_dep.py			   __pycache__
# 'Evaluation Code.gdoc'		   readme
#  extrinsic			   sdp_graph.py
#  Extrinsic.ipynb		   small.sdp
# 'FINAL_Biaffine Parser.ipynb'	  'Training Biaffine Semantic Dependency Parser.ipynb'
#  indexed_data.py		   train_or_use_parser.py
#  indexing.py			   Untitled0.ipynb

# %% [markdown]
# # **SMALL AUGMENTED EMBEDDINGS**

# %%
# !pip install sacremoses
# !python3 "/content/drive/MyDrive/CST/L98/train_or_use_parser.py" train "/content/drive/MyDrive/CST/L98/aug/small.sdp" "/content/drive/MyDrive/CST/L98/model/aug_small_emb" -g sdp -v "/content/drive/MyDrive/CST/L98/aug/small.sdp" -e loss
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 13.8 MB/s eta 0:00:00
# ...
# 2023-12-13 19:36:00.118946: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-13 19:36:00.119003: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-13 19:36:00.119054: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-13 19:36:01.655246: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# tokenizer_config.json: 100% 29.0/29.0 [00:00<00:00, 170kB/s]
# config.json: 100% 570/570 [00:00<00:00, 3.20MB/s]
# ...

# %% [markdown]
# l1-rerank

# %%
# !python3 "/content/drive/MyDrive/CST/L98/train_or_use_parser.py" test "/content/drive/MyDrive/CST/L98/l1-rerank.sdp" "/content/drive/MyDrive/CST/L98/model/aug_small_emb" -g sdp --out_parsed_file training.txt
# Out:
# 2023-12-13 22:57:16.296252: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-13 22:57:16.296326: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-13 22:57:16.296371: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-13 22:57:17.449549: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# tokenizer_config.json: 100% 29.0/29.0 [00:00<00:00, 153kB/s]
# config.json: 100% 570/570 [00:00<00:00, 3.37MB/s]
# vocab.txt: 100% 213k/213k [00:00<00:00, 1.59MB/s]
# tokenizer.json: 100% 436k/436k [00:00<00:00, 26.5MB/s]
# ...

# %%
# !python3 "/content/drive/MyDrive/CST/L98/eval_dep.py" training.txt.l
# Out:
# ALL UR 59.97 UP 69.56 UF 64.41
# ALL LR 54.99 LP 63.78 LF 59.06
# >40 UR 32.81 UP 43.21 UF 37.30
# >40 LR 29.62 LP 39.01 LF 33.67
# LABEL          ARG1 GOLD DIST:  0.78 (MAD  2.47) PRED DIST:  0.54 (MAD  3.48)
# LABEL          ARG1 GOLD DIR :  0.24 (MAD  0.94) PRED DIR :  0.23 (MAD  0.95)
# LABEL          ARG2 GOLD DIST: -1.79 (MAD  1.25) PRED DIST: -1.93 (MAD  1.89)
# LABEL          ARG2 GOLD DIR : -0.85 (MAD  0.27) PRED DIR : -0.78 (MAD  0.39)
# LABEL          ARG3 GOLD DIST: -2.75 (MAD  1.77) PRED DIST: -2.04 (MAD  2.04)
# LABEL          ARG3 GOLD DIR : -0.90 (MAD  0.19) PRED DIR : -0.79 (MAD  0.37)
# LABEL          ARG4 GOLD DIST: -1.50 (MAD  3.50) PRED DIST:  0.00 (MAD  0.00)
# LABEL          ARG4 GOLD DIR : -0.73 (MAD  0.47) PRED DIR :  0.00 (MAD  0.00)
# LABEL            BV GOLD DIST: -1.39 (MAD  0.53) PRED DIST: -1.45 (MAD  0.72)
# LABEL            BV GOLD DIR : -1.00 (MAD  0.00) PRED DIR : -0.97 (MAD  0.06)
# ...

# %% [markdown]
# l2-rerank

# %%
# !python3 "/content/drive/MyDrive/CST/L98/train_or_use_parser.py" test "/content/drive/MyDrive/CST/L98/l2-rerank.sdp" "/content/drive/MyDrive/CST/L98/model/aug_small_emb" -g sdp --out_parsed_file l2.txt
# Out:
# 2023-12-13 23:00:15.702139: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-13 23:00:15.702193: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-13 23:00:15.702232: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-13 23:00:16.870540: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Parsing /content/drive/MyDrive/CST/L98/l2-rerank.sdp with /content/drive/MyDrive/CST/L98/model/aug_small_emb/model ...
# loaded model /content/drive/MyDrive/CST/L98/model/aug_small_emb/model
# ...

# %%
# !python3 "/content/drive/MyDrive/CST/L98/eval_dep.py" l2.txt.l
# Out:
# ALL UR 57.78 UP 66.73 UF 61.94
# ALL LR 52.93 LP 61.13 LF 56.73
# >40 UR 28.23 UP 40.08 UF 33.12
# >40 LR 25.22 LP 35.80 LF 29.59
# LABEL          ARG1 GOLD DIST:  0.85 (MAD  2.41) PRED DIST:  0.54 (MAD  3.37)
# LABEL          ARG1 GOLD DIR :  0.26 (MAD  0.93) PRED DIR :  0.24 (MAD  0.94)
# LABEL          ARG2 GOLD DIST: -1.68 (MAD  1.44) PRED DIST: -1.94 (MAD  1.84)
# LABEL          ARG2 GOLD DIR : -0.83 (MAD  0.32) PRED DIR : -0.78 (MAD  0.39)
# LABEL          ARG3 GOLD DIST: -2.44 (MAD  2.29) PRED DIST: -1.52 (MAD  2.71)
# LABEL          ARG3 GOLD DIR : -0.80 (MAD  0.37) PRED DIR : -0.68 (MAD  0.54)
# LABEL          ARG4 GOLD DIST: -2.38 (MAD  2.79) PRED DIST:  0.00 (MAD  0.00)
# LABEL          ARG4 GOLD DIR : -0.69 (MAD  0.52) PRED DIR :  0.00 (MAD  0.00)
# LABEL            BV GOLD DIST: -1.39 (MAD  0.53) PRED DIST: -1.43 (MAD  0.68)
# LABEL            BV GOLD DIR : -1.00 (MAD  0.00) PRED DIR : -0.97 (MAD  0.06)
# ...

# %% [markdown]
# # **LARGE AUGMENTED EMBEDDINGS**

# %%
# !python3 "/content/drive/MyDrive/CST/L98/train_or_use_parser.py" train "/content/drive/MyDrive/CST/L98/aug/large.sdp" "/content/drive/MyDrive/CST/L98/model/aug_large_emb" -g sdp -v "/content/drive/MyDrive/CST/L98/aug/large.sdp" -e loss
# Out:
# 2023-12-13 23:28:25.009378: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-13 23:28:25.009435: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-13 23:28:25.009478: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-13 23:28:26.175320: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# There are 1 GPU(s) available.
# We will use GPU 0 (Tesla T4) of compute capability 7.5 with 15.84Gb total memory.
#
# loading sentences...
# Max sentence length: {'train': 71}
# Max sentence length: {'dev': 71}
# indices...
# ...

# %% [markdown]
# l1-rerank

# %%
# !python3 "/content/drive/MyDrive/CST/L98/train_or_use_parser.py" test "/content/drive/MyDrive/CST/L98/l1-rerank.sdp" "/content/drive/MyDrive/CST/L98/model/aug_large_emb" -g sdp --out_parsed_file l1.txt
# Out:
# 2023-12-14 09:31:41.126738: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-14 09:31:41.126796: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-14 09:31:41.127792: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-14 09:31:42.923097: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Parsing /content/drive/MyDrive/CST/L98/l1-rerank.sdp with /content/drive/MyDrive/CST/L98/model/aug_large_emb/model ...
# loaded model /content/drive/MyDrive/CST/L98/model/aug_large_emb/model
# ...

# %%
# !python3 "/content/drive/MyDrive/CST/L98/eval_dep.py" l1.txt.l
# Out:
# ALL UR 77.96 UP 77.95 UF 77.95
# ALL LR 72.01 LP 72.01 LF 72.01
# >40 UR 77.42 UP 74.34 UF 75.85
# >40 LR 72.46 LP 69.57 LF 70.99
# LABEL          ARG1 GOLD DIST:  0.78 (MAD  2.47) PRED DIST:  0.50 (MAD  2.57)
# LABEL          ARG1 GOLD DIR :  0.24 (MAD  0.94) PRED DIR :  0.17 (MAD  0.96)
# LABEL          ARG2 GOLD DIST: -1.79 (MAD  1.25) PRED DIST: -1.99 (MAD  1.22)
# LABEL          ARG2 GOLD DIR : -0.85 (MAD  0.27) PRED DIR : -0.86 (MAD  0.26)
# LABEL          ARG3 GOLD DIST: -2.75 (MAD  1.77) PRED DIST: -2.97 (MAD  1.48)
# LABEL          ARG3 GOLD DIR : -0.90 (MAD  0.19) PRED DIR : -0.97 (MAD  0.06)
# LABEL          ARG4 GOLD DIST: -1.50 (MAD  3.50) PRED DIST:  0.00 (MAD  0.00)
# LABEL          ARG4 GOLD DIR : -0.73 (MAD  0.47) PRED DIR :  0.00 (MAD  0.00)
# LABEL            BV GOLD DIST: -1.39 (MAD  0.53) PRED DIST: -1.40 (MAD  0.55)
# LABEL            BV GOLD DIR : -1.00 (MAD  0.00) PRED DIR : -1.00 (MAD  0.01)
# ...

# %% [markdown]
# l2-rerank

# %%
# !python3 "/content/drive/MyDrive/CST/L98/train_or_use_parser.py" test "/content/drive/MyDrive/CST/L98/l2-rerank.sdp" "/content/drive/MyDrive/CST/L98/model/aug_large_emb" -g sdp --out_parsed_file l2.txt
# Out:
# 2023-12-14 09:34:22.050867: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-14 09:34:22.050930: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-14 09:34:22.050982: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-14 09:34:23.848708: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Parsing /content/drive/MyDrive/CST/L98/l2-rerank.sdp with /content/drive/MyDrive/CST/L98/model/aug_large_emb/model ...
# loaded model /content/drive/MyDrive/CST/L98/model/aug_large_emb/model
# ...

# %%
# !python3 "/content/drive/MyDrive/CST/L98/eval_dep.py" l2.txt.l
# Out:
# ALL UR 72.93 UP 74.10 UF 73.51
# ALL LR 67.27 LP 68.35 LF 67.81
# >40 UR 71.64 UP 71.59 UF 71.61
# >40 LR 67.22 LP 67.18 LF 67.20
# LABEL          ARG1 GOLD DIST:  0.85 (MAD  2.41) PRED DIST:  0.55 (MAD  2.51)
# LABEL          ARG1 GOLD DIR :  0.26 (MAD  0.93) PRED DIR :  0.18 (MAD  0.96)
# LABEL          ARG2 GOLD DIST: -1.68 (MAD  1.44) PRED DIST: -1.95 (MAD  1.22)
# LABEL          ARG2 GOLD DIR : -0.83 (MAD  0.32) PRED DIR : -0.86 (MAD  0.27)
# LABEL          ARG3 GOLD DIST: -2.44 (MAD  2.29) PRED DIST: -3.05 (MAD  1.61)
# LABEL          ARG3 GOLD DIR : -0.80 (MAD  0.37) PRED DIR : -0.97 (MAD  0.05)
# LABEL          ARG4 GOLD DIST: -2.38 (MAD  2.79) PRED DIST:  0.00 (MAD  0.00)
# LABEL          ARG4 GOLD DIR : -0.69 (MAD  0.52) PRED DIR :  0.00 (MAD  0.00)
# LABEL            BV GOLD DIST: -1.39 (MAD  0.53) PRED DIST: -1.40 (MAD  0.55)
# LABEL            BV GOLD DIR : -1.00 (MAD  0.00) PRED DIR : -1.00 (MAD  0.01)
# ...

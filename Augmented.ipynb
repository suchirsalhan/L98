# %%
#needed dependencies for io in Drive
# !pip install -U -q PyDrive
# !pip install h5py
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
from google.colab import drive
drive.mount('/content/drive')
# !ls "/content/drive/MyDrive/CST/L98/"
# Out:
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#  aug				   l1-rerank.sdp
#  Augmented_2.ipynb		   l2-rerank.sdp
#  Augmented.ipynb		   L98_2.sdp
#  biaffine_parser.py		   large.sdp
# 'Biaffine Sentence_Length.ipynb'   Mixed.ipynb
#  conll09_ENG_test.conllu	   model
#  conll09_ENG_test.sdp		  'Model Outputs'
#  convert.py			   modules.py
#  data.py			   multilingual_MBERT.ipynb
#  dm_500.sdp			   multilingual_Parser.ipynb
#  dm.sdp				   multilingual_XLM.ipynb
#  eval_dep.py			   __pycache__
# 'Evaluation Code.gdoc'		   readme
#  extrinsic			   sdp_graph.py
#  Extrinsic.ipynb		   small.sdp
# 'FINAL_Biaffine Parser.ipynb'	  'Training Biaffine Semantic Dependency Parser.ipynb'
#  indexed_data.py		   train_or_use_parser.py
#  indexing.py			   Untitled0.ipynb

# %% [markdown]
# # SMALL AUGMENTED

# %%
# !pip install sacremoses
# !python3 "/content/drive/MyDrive/CST/L98/train_or_use_parser.py" train "/content/drive/MyDrive/CST/L98/aug/syn_small.sdp" "/content/drive/MyDrive/CST/L98/model/aug_small" -g sdp -v "/content/drive/MyDrive/CST/L98/aug/syn_small.sdp" -e loss
# Out:
# ...
# 2023-12-13 17:56:20.595429: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-13 17:56:20.595501: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-13 17:56:20.595544: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-13 17:56:21.851388: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# There are 1 GPU(s) available.
# We will use GPU 0 (Tesla T4) of compute capability 7.5 with 15.84Gb total memory.
#
# loading sentences...
# Max sentence length: {'train': 26}
# Max sentence length: {'dev': 26}
# indices...
# ...

# %% [markdown]
# l1-rerank

# %%
# !python3 "/content/drive/MyDrive/CST/L98/train_or_use_parser.py" test "/content/drive/MyDrive/CST/L98/l1-rerank.sdp" "/content/drive/MyDrive/CST/L98/model/aug_small" -g sdp --out_parsed_file training.txt
# Out:
# 2023-12-13 20:01:14.968233: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-13 20:01:14.968314: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-13 20:01:14.968364: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-13 20:01:17.103668: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Parsing /content/drive/MyDrive/CST/L98/l1-rerank.sdp with /content/drive/MyDrive/CST/L98/model/aug_small/model ...
# loaded model /content/drive/MyDrive/CST/L98/model/aug_small/model
# Max sentence length: {'toparse': 63}
# ...

# %%
# !python3 "/content/drive/MyDrive/CST/L98/eval_dep.py" training.txt.l
# Out:
# ALL UR 62.87 UP 60.04 UF 61.42
# ALL LR 57.13 LP 54.56 LF 55.82
# >40 UR 39.31 UP 31.54 UF 35.00
# >40 LR 34.69 LP 27.84 LF 30.89
# LABEL          ARG1 GOLD DIST:  0.78 (MAD  2.47) PRED DIST:  0.45 (MAD  4.17)
# LABEL          ARG1 GOLD DIR :  0.24 (MAD  0.94) PRED DIR :  0.19 (MAD  0.96)
# LABEL          ARG2 GOLD DIST: -1.79 (MAD  1.25) PRED DIST: -1.77 (MAD  2.46)
# LABEL          ARG2 GOLD DIR : -0.85 (MAD  0.27) PRED DIR : -0.67 (MAD  0.55)
# LABEL          ARG3 GOLD DIST: -2.75 (MAD  1.77) PRED DIST: -1.83 (MAD  1.98)
# LABEL          ARG3 GOLD DIR : -0.90 (MAD  0.19) PRED DIR : -0.71 (MAD  0.49)
# LABEL          ARG4 GOLD DIST: -1.50 (MAD  3.50) PRED DIST:  0.00 (MAD  0.00)
# LABEL          ARG4 GOLD DIR : -0.73 (MAD  0.47) PRED DIR :  0.00 (MAD  0.00)
# LABEL            BV GOLD DIST: -1.39 (MAD  0.53) PRED DIST: -1.58 (MAD  1.00)
# LABEL            BV GOLD DIR : -1.00 (MAD  0.00) PRED DIR : -0.93 (MAD  0.13)
# ...

# %% [markdown]
# l2-rerank

# %%
# !python3 "/content/drive/MyDrive/CST/L98/train_or_use_parser.py" test "/content/drive/MyDrive/CST/L98/l2-rerank.sdp" "/content/drive/MyDrive/CST/L98/model/aug_small" -g sdp --out_parsed_file l2.txt
# Out:
# 2023-12-13 20:04:03.262599: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-13 20:04:03.262663: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-13 20:04:03.262706: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-13 20:04:04.546767: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Parsing /content/drive/MyDrive/CST/L98/l2-rerank.sdp with /content/drive/MyDrive/CST/L98/model/aug_small/model ...
# loaded model /content/drive/MyDrive/CST/L98/model/aug_small/model
# Max sentence length: {'toparse': 59}
# ...

# %%
# !python3 "/content/drive/MyDrive/CST/L98/eval_dep.py" l2.txt.l
# Out:
# ALL UR 60.67 UP 58.33 UF 59.48
# ALL LR 54.94 LP 52.82 LF 53.86
# >40 UR 36.59 UP 29.91 UF 32.91
# >40 LR 32.58 LP 26.63 LF 29.30
# LABEL          ARG1 GOLD DIST:  0.85 (MAD  2.41) PRED DIST:  0.44 (MAD  4.01)
# LABEL          ARG1 GOLD DIR :  0.26 (MAD  0.93) PRED DIR :  0.20 (MAD  0.96)
# LABEL          ARG2 GOLD DIST: -1.68 (MAD  1.44) PRED DIST: -1.80 (MAD  2.40)
# LABEL          ARG2 GOLD DIR : -0.83 (MAD  0.32) PRED DIR : -0.68 (MAD  0.54)
# LABEL          ARG3 GOLD DIST: -2.44 (MAD  2.29) PRED DIST: -1.36 (MAD  1.81)
# LABEL          ARG3 GOLD DIR : -0.80 (MAD  0.37) PRED DIR : -0.64 (MAD  0.60)
# LABEL          ARG4 GOLD DIST: -2.38 (MAD  2.79) PRED DIST:  0.00 (MAD  0.00)
# LABEL          ARG4 GOLD DIR : -0.69 (MAD  0.52) PRED DIR :  0.00 (MAD  0.00)
# LABEL            BV GOLD DIST: -1.39 (MAD  0.53) PRED DIST: -1.57 (MAD  0.98)
# LABEL            BV GOLD DIR : -1.00 (MAD  0.00) PRED DIR : -0.93 (MAD  0.14)
# ...

# %% [markdown]
# # LARGE AUGMENTED

# %%
# !python3 "/content/drive/MyDrive/CST/L98/train_or_use_parser.py" train "/content/drive/MyDrive/CST/L98/aug/syn_large.sdp" "/content/drive/MyDrive/CST/L98/model/aug_large" -g sdp -v "/content/drive/MyDrive/CST/L98/aug/syn_large.sdp" -e loss
# Out:
# 2023-12-13 23:05:12.958428: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-13 23:05:12.958514: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-13 23:05:12.958565: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-13 23:05:14.325054: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# tokenizer_config.json: 100% 29.0/29.0 [00:00<00:00, 131kB/s]
# config.json: 100% 570/570 [00:00<00:00, 2.51MB/s]
# vocab.txt: 100% 213k/213k [00:00<00:00, 6.43MB/s]
# tokenizer.json: 100% 436k/436k [00:00<00:00, 6.57MB/s]
# ...

# %% [markdown]
# l1-rerank

# %%
# !python3 "/content/drive/MyDrive/CST/L98/train_or_use_parser.py" test "/content/drive/MyDrive/CST/L98/l1-rerank.sdp" "/content/drive/MyDrive/CST/L98/model/aug_large" -g sdp --out_parsed_file l1.txt
# Out:
# 2023-12-14 09:30:24.927036: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-14 09:30:24.927096: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-14 09:30:24.927139: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-14 09:30:26.351809: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Parsing /content/drive/MyDrive/CST/L98/l1-rerank.sdp with /content/drive/MyDrive/CST/L98/model/aug_large/model ...
# loaded model /content/drive/MyDrive/CST/L98/model/aug_large/model
# Max sentence length: {'toparse': 63}
# ...

# %%
# !python3 "/content/drive/MyDrive/CST/L98/eval_dep.py" l1.txt.l
# Out:
# ALL UR 76.79 UP 78.53 UF 77.65
# ALL LR 70.81 LP 72.41 LF 71.60
# >40 UR 75.77 UP 73.98 UF 74.86
# >40 LR 70.73 LP 69.06 LF 69.88
# LABEL          ARG1 GOLD DIST:  0.78 (MAD  2.47) PRED DIST:  0.46 (MAD  2.54)
# LABEL          ARG1 GOLD DIR :  0.24 (MAD  0.94) PRED DIR :  0.18 (MAD  0.97)
# LABEL          ARG2 GOLD DIST: -1.79 (MAD  1.25) PRED DIST: -1.92 (MAD  1.22)
# LABEL          ARG2 GOLD DIR : -0.85 (MAD  0.27) PRED DIR : -0.85 (MAD  0.28)
# LABEL          ARG3 GOLD DIST: -2.75 (MAD  1.77) PRED DIST: -2.62 (MAD  1.24)
# LABEL          ARG3 GOLD DIR : -0.90 (MAD  0.19) PRED DIR : -0.96 (MAD  0.07)
# LABEL          ARG4 GOLD DIST: -1.37 (MAD  3.19) PRED DIST:  0.00 (MAD  0.00)
# LABEL          ARG4 GOLD DIR :  0.03 (MAD  1.00) PRED DIR :  0.00 (MAD  0.00)
# LABEL            BV GOLD DIST: -1.39 (MAD  0.53) PRED DIST: -1.40 (MAD  0.55)
# LABEL            BV GOLD DIR : -1.00 (MAD  0.00) PRED DIR : -1.00 (MAD  0.01)
# ...

# %% [markdown]
# l2-rerank

# %%
# !python3 "/content/drive/MyDrive/CST/L98/train_or_use_parser.py" test "/content/drive/MyDrive/CST/L98/l2-rerank.sdp" "/content/drive/MyDrive/CST/L98/model/aug_large" -g sdp --out_parsed_file l2.txt
# Out:
# 2023-12-14 09:33:05.323333: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-14 09:33:05.323386: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-14 09:33:05.323427: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-14 09:33:06.526668: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Parsing /content/drive/MyDrive/CST/L98/l2-rerank.sdp with /content/drive/MyDrive/CST/L98/model/aug_large/model ...
# loaded model /content/drive/MyDrive/CST/L98/model/aug_large/model
# Max sentence length: {'toparse': 59}
# ...

# %%
# !python3 "/content/drive/MyDrive/CST/L98/eval_dep.py" l2.txt.l
# Out:
# ALL UR 72.13 UP 74.71 UF 73.40
# ALL LR 66.42 LP 68.80 LF 67.59
# >40 UR 70.57 UP 71.14 UF 70.85
# >40 LR 66.09 LP 66.62 LF 66.35
# LABEL          ARG1 GOLD DIST:  0.85 (MAD  2.41) PRED DIST:  0.50 (MAD  2.49)
# LABEL          ARG1 GOLD DIR :  0.26 (MAD  0.93) PRED DIR :  0.20 (MAD  0.96)
# LABEL          ARG2 GOLD DIST: -1.68 (MAD  1.44) PRED DIST: -1.88 (MAD  1.22)
# LABEL          ARG2 GOLD DIR : -0.83 (MAD  0.32) PRED DIR : -0.85 (MAD  0.28)
# LABEL          ARG3 GOLD DIST: -2.44 (MAD  2.29) PRED DIST: -2.50 (MAD  1.22)
# LABEL          ARG3 GOLD DIR : -0.80 (MAD  0.37) PRED DIR : -0.96 (MAD  0.07)
# LABEL          ARG4 GOLD DIST: -1.29 (MAD  3.02) PRED DIST:  0.00 (MAD  0.00)
# LABEL          ARG4 GOLD DIR : -0.00 (MAD  1.00) PRED DIR :  0.00 (MAD  0.00)
# LABEL            BV GOLD DIST: -1.39 (MAD  0.53) PRED DIST: -1.41 (MAD  0.56)
# LABEL            BV GOLD DIR : -1.00 (MAD  0.00) PRED DIR : -1.00 (MAD  0.01)
# ...
